# %%
import numpy as np

# %%
np.random.seed(1)

# %%
x=np.random.randint(0,50,100)

# %%
x
# Out:
# array([43, 43, 10, 34, 33, 11,  2, 10, 27,  5, 26,  3, 31, 11,  3,  1, 13,
#        17,  8, 38,  4,  6, 12,  9,  5, 15, 20, 31, 26,  7, 43,  2, 32, 46,
#        11, 18, 44,  0, 37, 47,  9, 26, 20, 15,  1,  5,  2, 25, 28, 19, 43,
#        17,  5, 45, 15, 10, 29, 17, 17, 46,  7, 17, 22,  0,  7, 29, 28, 35,
#        43, 34, 40,  5, 28, 41, 34, 34, 19, 13, 37, 25,  4, 43, 11, 29, 12,
#        25, 32, 40, 42, 23, 25, 43, 40, 24, 31, 28,  0, 22, 24, 22])

# %%
y=x-np.random.normal(0,10,100)

# %%
y
# Out:
# array([ 47.97530203,  53.23925419,   5.54226436,  41.30859186,
#         22.3524665 ,  -0.25816867,  -6.42583785,  20.8018492 ,
#         31.01954426,  19.54713663,  40.6019604 ,  15.92529625,
#         29.38555572,  16.4246864 ,  -5.31760063, -14.18088322,
#         23.37402326,  12.33841328,   7.51902972,  49.89454346,
#          5.76772177,   3.90067693,  35.9764329 ,  21.5371414 ,
#         17.49093655,  15.10003452,  32.48464158,  39.26085781,
#         22.06160703,   2.48206191,  23.84017538,  15.1343719 ,
#         31.68230769,  57.71636366,   3.38600023,  22.29873695,
#         32.79359875, -14.40730126,  37.83278573,  57.62493145,
#         18.79712687,  21.9186795 ,  10.73249971,  -4.63625691,
#         25.95232117,  15.86482196,  -8.85140673,  21.92197378,
#         23.17457799,   3.73088779,  46.43950613,  30.38022684,
#          2.34742757,  53.41843354,  13.47556127,  13.28800552,
#         39.96243358,   1.79082054,  11.06103098,  53.49703817,
#         -4.1059155 ,  23.00313952,  -8.64294608,  14.44327595,
#          6.30914042,  31.25849026,  40.13944048,  41.69490457,
#         62.95416915,  45.22499577,  36.01201585,   5.25127218,
#         15.44007259,  47.20750251,  24.25897152,  32.67908097,
#         31.70599602,  20.24205807,  36.23086932,  18.85379814,
#          3.73441704,  50.02076086,  10.31016918,  33.54457789,
#          7.3857109 ,  36.25854979,  14.04631395,  44.14810154,
#         42.28515959,   7.65693887,  36.88668874,  42.02876986,
#         49.80102954,  27.57767251,  32.78612917,  10.36997202,
#         -9.91506188,  23.31314032,  48.65997243,  14.50814656])

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.81201191],
#        [0.81201191, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
#-ve corr

# %%
y=(100-x)+np.random.normal(0,10,100)

# %%
y
# Out:
# array([ 60.79813691,  65.81879579,  76.65486725,  69.6135347 ,
#         76.65514728,  89.7232592 , 105.43828492,  86.08969527,
#         70.31959536, 101.43883465,  80.54620037, 100.00195039,
#         72.92687052,  85.5290403 ,  84.93334061, 111.95487009,
#         90.90118032,  72.95318677,  95.14776191,  65.40144814,
#        100.45115762,  95.25095939,  74.98190557,  94.87410579,
#         76.34163211,  76.92317882,  80.09018002,  71.36285809,
#         64.98190017,  89.89417213,  45.48356584, 115.99690012,
#         64.79564981,  43.30750781, 112.54891857,  67.1554596 ,
#         55.30650942, 115.18257714,  47.26634478,  47.7109567 ,
#         86.35726209,  78.78566158,  69.33197201,  98.68638332,
#         99.59323223,  94.52407963,  80.84739445,  82.4999135 ,
#         68.405792  ,  76.70250015,  54.22873337, 101.81395641,
#         94.83383577,  68.02431114,  71.29067231,  81.65996323,
#         69.15350338,  89.93989172,  66.14719958,  53.51141761,
#         90.29349315,  91.92535014,  88.56177673,  90.1745397 ,
#         90.93606515,  69.32893667,  77.0275312 ,  71.93985078,
#         42.3061092 ,  71.17330011,  74.87931566, 108.25451864,
#         67.04109621,  57.02301626,  64.91746187,  76.28756025,
#         73.20894675,  95.35331713,  48.13543865,  94.07778157,
#         86.56559785,  54.02022547,  86.87010202,  69.70515864,
#         98.64672796,  66.31620887,  83.61339336,  70.41572015,
#         42.25960544,  77.18605313,  70.61207774,  52.47158188,
#         57.54704928,  82.6492764 ,  71.459613  ,  86.83694092,
#         99.30628216,  91.48989608,  89.59599169,  82.25733631])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
y=np.random.randint(0,50,100)

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
import pandas as pd

# %%
df=pd.DataFrame({'a':np.random.randint(0,50,1000)})
df['b']=df['a']+np.random.normal(0,10,1000)
df['c']=df['a']+np.random.normal(0,5,1000)
df['d']=np.random.randint(0,5,1000)
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.818516  0.943996  0.055046
# b  0.818516  1.000000  0.776448  0.049985
# c  0.943996  0.776448  1.000000  0.046216
# d  0.055046  0.049985  0.046216  1.000000

# %%
pd.plotting.scatter_matrix(df,figsize=(6,6))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show()
